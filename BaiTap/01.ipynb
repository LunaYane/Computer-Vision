# %%
#Shift + enter: run code and thêm 1 dòng mới

# %%
#Ctrl+ Enter: run code

# %%
# !pip install pillow

# %%
#Thêm thư viện
from PIL import Image

# %%
#Khai báo 1 biến chứa thư mục
dir = 'C:/Users/pc/OneDrive/Pictures/Mihoyo'

# %%
#Khai báo dẫn ảnh
image_path = dir + "/T1.JPG"
print(image_path)
# Out:
# C:/Users/pc/OneDrive/Pictures/Mihoyo/T1.JPG

# %%
#Sử dụng Image.open() để đọc ảnh
img01 = Image.open(image_path)

# %%
Image.open(image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1063x1063>

# %%
print("Định dạng ảnh:", img01.format)
print("Kích thước ảnh:", img01.size)
# Out:
# Định dạng ảnh: JPEG
# Kích thước ảnh: (1063, 1063)

# %%
# Save & Reformat image.
newImagePath = dir + "/T1.jpg"
newImagePathPNG = dir + "/T1.png"
img01.save(newImagePath)
img01.save(newImagePathPNG)

# %%
img01.close()
