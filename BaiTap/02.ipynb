# %%
#Thêm thư viện
from PIL import Image
from Imgtools import *

# %%
imageDir = "C:/Users/pc/OneDrive/Pictures/Mihoyo"

# %%
imageList = get_image_list(imageDir)
for image in imageList:
    display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1063x1063>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1063x1063>
